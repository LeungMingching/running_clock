# %%
import requests

# %%
my_key = '9566c1a0111ad609695ccd555ce0c2bc'
url = 'https://restapi.amap.com/v3/direction/driving'

# %%
params = {
    'key': my_key,
    'origin': '116.481028,39.989643',
    'destination': '116.465302,40.004717',
    'extensions': 'all',
    'output': 'json'
}

# %%
ret = requests.get(
    url=url,
    params=params
)

# %%
print(ret.text)
# Out:
# {"status":"1","info":"OK","infocode":"10000","count":"1","route":{"origin":"116.481028,39.989643","destination":"116.465302,40.004717","taxi_cost":"13","paths":[{"distance":"3238","duration":"899","strategy":"速度最快","tolls":"0","toll_distance":"0","steps":[{"instruction":"向北行驶109米右转","orientation":"北","distance":"109","tolls":"0","toll_distance":"0","toll_road":[],"duration":"46","polyline":"116.480891,39.98937;116.480891,39.98937;116.480553,39.989606;116.480548,39.98966;116.480596,39.989708;116.481095,39.990051","action":"右转","assistant_action":[],"tmcs":[{"lcode":[],"distance":"1","status":"未知","polyline":"116.480891,39.98937;116.480891,39.98937"},{"lcode":[],"distance":"51","status":"未知","polyline":"116.480891,39.98937;116.480553,39.989606;116.480548,39.98966;116.480596,39.989708"},{"lcode":[],"distance":"57","status":"未知","polyline":"116.480596,39.989708;116.481095,39.990051"}],"cities":[{"name":"北京城区","citycode":"010","adcode":"110100","districts":[{"name":"朝阳区","adcode":"110105"
# ...
